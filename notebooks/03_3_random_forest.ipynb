# %% [markdown]
# # Random Forest Classifier
# * In this notebook we are going to train a model using Random Forest, experiment with various params using grid search and try to come up with best `Random Forest` version.

# %% [markdown]
# ## Install Libraries

# %%
# %pip install scikit-learn

# %% [markdown]
# ## Import Libraries

# %%
import os
import sys
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,recall_score,precision_score,precision_recall_curve
import seaborn as sns


# Build an absolute path from this notebook's parent directory
module_path = os.path.abspath(os.path.join('..'))

# Add to sys.path if not already present
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src.utils import preprocessing
from src.utils import common
from src.utils.training import refit_strategy

# %% [markdown]
# ## Initialize Directories

# %%
data_root_dir = Path("..", "data/")
models_root_dir = Path("..", "models/")

# %% [markdown]
# ## Read Data

# %%
X_train = pd.read_csv(Path(data_root_dir,"X_train.csv"))
y_train = pd.read_csv(Path(data_root_dir,"y_train.csv"))

# %% [markdown]
# ## Training Default Model

# %%
# import sklearn


# sklearn.metrics.get_scorer_names()

# %%
from sklearn.discriminant_analysis import StandardScaler
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.pipeline import Pipeline


default_random_forest_model = RandomForestClassifier(random_state=42)

model_pipeline = Pipeline([
    ("preprocessing", preprocessing.pipeline),
    ("normalizing", StandardScaler()),
    ("prediction", default_random_forest_model)
])

scoring = ["recall", "precision", "f1"]

default_random_forest_scores = cross_validate(
    estimator=model_pipeline, 
    X=X_train, 
    y=y_train.values.ravel(), 
    cv=3, scoring=scoring,
    n_jobs=-1, verbose=2)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# [CV] END .................................................... total time=   3.3s
# [CV] END .................................................... total time=   3.3s
# [CV] END .................................................... total time=   3.3s
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    4.7s finished

# %%
default_random_forest_scores
# Out:
# {'fit_time': array([2.47265124, 2.36221004, 2.36410451]),
#  'score_time': array([0.80415249, 0.90820003, 0.88891435]),
#  'test_recall': array([0.88475666, 0.87511478, 0.87396694]),
#  'test_precision': array([0.84946   , 0.84094419, 0.85454545]),
#  'test_f1': array([0.86674913, 0.85768928, 0.86414709])}

# %%
cv_scores = default_random_forest_scores

# %%
mean_recall,mean_precision,mean_f1 = common.calculate_mean_from_cv(default_random_forest_scores)
# Out:
# Mean Recall: 0.877946127946128, Mean Precision: 0.877946127946128,Mean F1: 0.8628618320927531

# %%
# commenting this code out to avoid overwriting the metrics file. 
common.update_models_metrics("Random Forest", "v0", mean_recall,mean_precision,mean_f1)
# Out:
#                  model version    recall  precision        f1  \
# 0  Logistic Regression      v0  0.885369   0.885369  0.870934
# 1  Logistic Regression      v1  0.885675   0.857110  0.871140
# 2  Logistic Regression      v2  0.886746   0.857321  0.871766
# 3           Linear SVC      v0  0.887511   0.887511  0.871667
# 4           Linear SVC      v1  0.887435   0.856400  0.871625
# 5           Linear SVC      v2  0.887894   0.856845  0.872076
# 6        Random Forest      v0  0.877870   0.877870  0.862945
# 7        Random Forest      v1  0.881772   0.848675  0.864893
# 8        Random Forest      v0  0.877946   0.877946  0.862862
#
#                             file
# 0                            NaN
# 1  logistic_regression_v1.joblib
# 2  logistic_regression_v2.joblib
# 3                            NaN
# 4           linear_svc_v1.joblib
# 5           linear_svc_v2.joblib
# 6                            NaN
# 7        random_forest_v1.joblib
# 8                            N/A

# %% [markdown]
# ## GridSearch CV v1

# %%
## checking params
# preprocessing.pipeline.get_params()

# %%
from sklearn.model_selection import GridSearchCV


model_pipeline = Pipeline([
    ("preprocessing", preprocessing.pipeline),
    ("normalizing", StandardScaler()),
    ("prediction", RandomForestClassifier(random_state=42))
])

scoring = ["recall", "precision", "f1"]

param_grid = {
    "prediction__n_estimators": [250,300,350,400,500],
    "prediction__criterion": ["gini", "entropy", "log_loss"],
    "prediction__max_features": ["sqrt", "log2", None]
}

grid_search = GridSearchCV(model_pipeline, param_grid,
                           scoring=scoring, cv=3, n_jobs=-1, refit=refit_strategy)
grid_search.fit(X_train, y_train.values.ravel())
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocessing',
#                                         ColumnTransformer(transformers=[('preprocess_gender',
#                                                                          Pipeline(steps=[('default_cat_pipeline',
#                                                                                           Pipeline(steps=[('fill_empty_strings',
#                                                                                                            FunctionTransformer(feature_names_out='one-to-one',
#                                                                                                                                func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                                                                                           ('strip_spaces',
#                                                                                                            FunctionTransformer(feature_names_ou...
#                                                                           'financial_stress'])])),
#                                        ('normalizing', StandardScaler()),
#                                        ('prediction',
#                                         RandomForestClassifier(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'prediction__criterion': ['gini', 'entropy',
#                                                    'log_loss'],
#                          'prediction__max_features': ['sqrt', 'log2', None],
#                          'prediction__n_estimators': [250, 300, 350, 400, 500]},
#              refit=<function refit_strategy at 0x7fa884422980>,
#              scoring=['recall', 'precision', 'f1'])

# %%
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best Scores : {grid_search.best_index_}")
average_recall,average_precision,average_f1 = common.read_best_mean_grid_search_metrics(grid_search.cv_results_,grid_search.best_index_)
# Out:
# Best Parameters: {'prediction__criterion': 'log_loss', 'prediction__max_features': 'sqrt', 'prediction__n_estimators': 400}
# Best Scores : 33
# Mean Recall: 0.882843587389042, Mean Precision: 0.8490424292899217,Mean F1: 0.8655937899834956

# %%
# commenting this code out to avoid overwriting the metrics file.
_, file_name = common.save_model(
    "Random Forest", "v1", grid_search.best_estimator_)
common.update_models_metrics("Random Forest", "v1", average_recall,
                             average_precision, average_f1, file_name=file_name)
common.update_model_params(
    "RandomForest", "v1", grid_search.best_params_)
# Out:
# [{'name': 'LogisticRegression',
#   'version': 'v1',
#   'params': {'prediction__C': 1,
#    'prediction__penalty': 'l1',
#    'prediction__solver': 'liblinear'}},
#  {'name': 'LogisticRegression',
#   'version': 'v2',
#   'params': {'prediction__C': 1,
#    'prediction__penalty': 'l2',
#    'prediction__solver': 'saga',
#    'preprocessing__age_pipeline__age_encoding__age_range_encoding__encoding': 'ordinal',
#    'preprocessing__cgpa_pipeline__cgpa_encoding__cgpa_range_encoding__encoding': 'ordinal',
#    'preprocessing__degree_pipeline__degree_encoding__degree_level_encoding__encoding': 'ordinal',
#    'preprocessing__dietary_habits_pipeline__dietary_habits_encoding__encoding': 'ordinal',
#    'preprocessing__hours_pipeline__hours_encoding__hours_range_encoding__encoding': 'onehot',
#    'preprocessing__sleep_duration_pipeline__sleep_duration_encoding__encoding': 'ordinal'}},
#  {'name': 'LinearSVC',
#   'version': 'v1',
#   'params': {'prediction__C': 10, 'prediction__penalty': 'l1'}},
#  {'name': 'LinearSVC',
#   'version': 'v2',
#   'params': {'prediction__C': 0.1,
#    'prediction__penalty': 'l1',
#    'preprocessing__age_pipeline__age_encoding__age_range_encoding__encoding': 'ordinal',
#    'preprocessing__cgpa_pipeline__cgpa_encoding__cgpa_range_encoding__encoding': 'ordinal',
#    'preprocessing__degree_pipeline__degree_encoding__degree_level_encoding__encoding': 'ordinal',
#    'preprocessing__dietary_habits_pipeline__dietary_habits_encoding__encoding': 'ordinal',
#    'preprocessing__hours_pipeline__hours_encoding__hours_range_encoding__encoding': 'onehot',
#    'preprocessing__sleep_duration_pipeline__sleep_duration_encoding__encoding': 'onehot'}},
#  {'name': 'RandomForest',
#   'version': 'v1',
#   'params': {'prediction__criterion': 'entropy',
#    'prediction__max_features': 'sqrt',
#    'prediction__n_estimators': 250}},
#  {'name': 'RandomForest',
#   'version': 'v1',
#   'params': {'prediction__criterion': 'log_loss',
#    'prediction__max_features': 'sqrt',
#    'prediction__n_estimators': 400}}]

# %% [markdown]
# ## GridSearch CV v2

# %%
preprocessing.pipeline.get_params(deep=True)
# Out:
# {'force_int_remainder_cols': True,
#  'n_jobs': None,
#  'remainder': 'drop',
#  'sparse_threshold': 0.3,
#  'transformer_weights': None,
#  'transformers': [('preprocess_gender',
#    Pipeline(steps=[('default_cat_pipeline',
#                     Pipeline(steps=[('fill_empty_strings',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                     ('strip_spaces',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                     ('to_lower_case',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#                                     ('normalize_unicode',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function normalize_unicode_fn at 0x7fa8842c9f80>))])),
#                    ('encode_gender',
#                     OneHotEncoder(handle_unknown='ignore', sparse_output=False))]),
#    ['gender']),
#   ('preprocess_profession',
#    Pipeline(steps=[('default_cat_pipeline',
#                     Pipeline(steps=[('fill_empty_strings',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                     ('strip_spaces',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                     ('to_lower_case',
#                                      FunctionTransformer(feature_names...
#                                                          func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#                                     ('normalize_unicode',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function normalize_unicode_fn at 0x7fa8842c9f80>))])),
#                    ('map_profession',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function map_working_profession_fn at 0x7fa8842ca020>)),
#                    ('encode_profession',
#                     OneHotEncoder(handle_unknown='ignore', sparse_output=False))]),
#    ['profession']),
#   ('sleep_duration_pipeline',
#    Pipeline(steps=[('default_cat_pipeline',
#                     Pipeline(steps=[('fill_empty_strings',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                     ('strip_spaces',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                     ('to_lower_case',
#                                      FunctionTransformer(feature_names...
#                    ('sleep_duration_clean',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function clean_sleep_duration_fn at 0x7fa8842ca0c0>)),
#                    ('sleep_duration_mapping',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function map_sleep_duration_fn at 0x7fa8842ca160>)),
#                    ('sleep_duration_encoding',
#                     CustomEncoder(categories=[['lt_5', 'bt_5_6', 'bt_7_8',
#                                                'gt_8']]))]),
#    ['sleep_duration']),
#   ('dietary_habits_pipeline',
#    Pipeline(steps=[('default_cat_pipeline',
#                     Pipeline(steps=[('fill_empty_strings',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                     ('strip_spaces',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                     ('to_lower_case',
#                                      FunctionTransformer(feature_names...
#                                     ('normalize_unicode',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function normalize_unicode_fn at 0x7fa8842c9f80>))])),
#                    ('dietary_habits_mapping',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function map_dietary_habits_fn at 0x7fa8842ca200>)),
#                    ('dietary_habits_encoding',
#                     CustomEncoder(categories=[['unhealthy', 'moderate',
#                                                'healthy']]))]),
#    ['dietary_habits']),
#   ('degree_pipeline',
#    Pipeline(steps=[('default_cat_pipeline',
#                     Pipeline(steps=[('fill_empty_strings',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                     ('strip_spaces',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                     ('to_lower_case',
#                                      FunctionTransformer(feature_names...
#                     FunctionTransformer(feature_names_out=<function map_degree_feature_names at 0x7fa8842ca340>,
#                                         func=<function map_degree_fn at 0x7fa8842ca520>)),
#                    ('degree_encoding',
#                     ColumnTransformer(transformers=[('degree_field_encoding',
#                                                      OneHotEncoder(handle_unknown='ignore',
#                                                                    sparse_output=False),
#                                                      ['degree_field']),
#                                                     ('degree_level_encoding',
#                                                      CustomEncoder(categories=[['unknown',
#                                                                                 'high_school',
#                                                                                 'bachelor',
#                                                                                 'master',
#                                                                                 'doctorate']]),
#                                                      ['degree_level'])]))]),
#    ['degree']),
#   ('suicidal_thoughts_pipeline',
#    Pipeline(steps=[('default_cat_pipeline',
#                     Pipeline(steps=[('fill_empty_strings',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                     ('strip_spaces',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                     ('to_lower_case',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#                                     ('normalize_unicode',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function normalize_unicode_fn at 0x7fa8842c9f80>))])),
#                    ('suididal_thoughts_encoding',
#                     OneHotEncoder(handle_unknown='ignore', sparse_output=False))]),
#    ['suicidal_thoughts']),
#   ('family_history_pipeline',
#    Pipeline(steps=[('default_cat_pipeline',
#                     Pipeline(steps=[('fill_empty_strings',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                     ('strip_spaces',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                     ('to_lower_case',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#                                     ('normalize_unicode',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function normalize_unicode_fn at 0x7fa8842c9f80>))])),
#                    ('family_history_encoding',
#                     OneHotEncoder(handle_unknown='ignore', sparse_output=False))]),
#    ['family_history']),
#   ('city_pipeline',
#    Pipeline(steps=[('default_cat_pipeline',
#                     Pipeline(steps=[('fill_empty_strings',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                     ('strip_spaces',
#                                      FunctionTransformer(feature_names_out='one-to-one',
#                                                          func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                     ('to_lower_case',
#                                      FunctionTransformer(feature_names...
#                                         func=<function map_city_fn at 0x7fa8842ca700>)),
#                    ('city_verification',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function verify_city_fn at 0x7fa8842caa20>)),
#                    ('city_depression_ratio', MapCityDepressionRatio()),
#                    ('city_cluster_similarity', ClusterSimilarityTransformer()),
#                    ('drop_lat_long',
#                     ConditionalDropper(columns_to_drop=['city', 'lat', 'long']))]),
#    ['city']),
#   ('age_pipeline',
#    Pipeline(steps=[('default_num_pipeline',
#                     Pipeline(steps=[('imputer',
#                                      SimpleImputer(strategy='median'))])),
#                    ('map_age_bins',
#                     FunctionTransformer(feature_names_out=<function map_age_bins_feature_names at 0x7fa8842cb560>,
#                                         func=<function map_age_bins_fn at 0x7fa8842cb600>)),
#                    ('age_encoding',
#                     ColumnTransformer(transformers=[('age_range_encoding',
#                                                      CustomEncoder(categories=[['18_to_23',
#                                                                                 '23_to_28',
#                                                                                 '28_to_33',
#                                                                                 'gte_33']]),
#                                                      ['age_range'])]))]),
#    ['age']),
#   ('cgpa_pipeline',
#    Pipeline(steps=[('default_num_pipeline',
#                     Pipeline(steps=[('imputer',
#                                      SimpleImputer(strategy='median'))])),
#                    ('map_cgpa_bins',
#                     FunctionTransformer(feature_names_out=<function map_cgpa_bins_feature_names at 0x7fa8842cb6a0>,
#                                         func=<function map_cgpa_bins_fn at 0x7fa8842cb740>)),
#                    ('cgpa_encoding',
#                     ColumnTransformer(transformers=[('cgpa_range_encoding',
#                                                      CustomEncoder(categories=[['lt_4',
#                                                                                 '4_to_7',
#                                                                                 'gte_7']]),
#                                                      ['cgpa_range'])]))]),
#    ['cgpa']),
#   ('hours_pipeline',
#    Pipeline(steps=[('default_num_pipeline',
#                     Pipeline(steps=[('imputer',
#                                      SimpleImputer(strategy='median'))])),
#                    ('map_hours_bins',
#                     FunctionTransformer(feature_names_out=<function map_hours_bins_feature_names at 0x7fa8842cb7e0>,
#                                         func=<function map_hours_bins_fn at 0x7fa8842cb880>)),
#                    ('hours_encoding',
#                     ColumnTransformer(transformers=[('hours_range_encoding',
#                                                      CustomEncoder(categories=[['lt_4',
#                                                                                 '4_to_8',
#                                                                                 'gte_8']]),
#                                                      ['hours_range'])]))]),
#    ['work_study_hours']),
#   ('ratings_column_pipeline',
#    Pipeline(steps=[('default_num_pipeline',
#                     Pipeline(steps=[('imputer',
#                                      SimpleImputer(strategy='median'))]))]),
#    ['academic_pressure', 'study_satisfaction', 'financial_stress'])],
#  'verbose': False,
#  'verbose_feature_names_out': True,
#  'preprocess_gender': Pipeline(steps=[('default_cat_pipeline',
#                   Pipeline(steps=[('fill_empty_strings',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                   ('strip_spaces',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                   ('to_lower_case',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#                                   ('normalize_unicode',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function normalize_unicode_fn at 0x7fa8842c9f80>))])),
#                  ('encode_gender',
#                   OneHotEncoder(handle_unknown='ignore', sparse_output=False))]),
#  'preprocess_profession': Pipeline(steps=[('default_cat_pipeline',
#                   Pipeline(steps=[('fill_empty_strings',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                   ('strip_spaces',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                   ('to_lower_case',
#                                    FunctionTransformer(feature_names...
#                                                        func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#                                   ('normalize_unicode',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function normalize_unicode_fn at 0x7fa8842c9f80>))])),
#                  ('map_profession',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function map_working_profession_fn at 0x7fa8842ca020>)),
#                  ('encode_profession',
#                   OneHotEncoder(handle_unknown='ignore', sparse_output=False))]),
#  'sleep_duration_pipeline': Pipeline(steps=[('default_cat_pipeline',
#                   Pipeline(steps=[('fill_empty_strings',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                   ('strip_spaces',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                   ('to_lower_case',
#                                    FunctionTransformer(feature_names...
#                  ('sleep_duration_clean',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function clean_sleep_duration_fn at 0x7fa8842ca0c0>)),
#                  ('sleep_duration_mapping',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function map_sleep_duration_fn at 0x7fa8842ca160>)),
#                  ('sleep_duration_encoding',
#                   CustomEncoder(categories=[['lt_5', 'bt_5_6', 'bt_7_8',
#                                              'gt_8']]))]),
#  'dietary_habits_pipeline': Pipeline(steps=[('default_cat_pipeline',
#                   Pipeline(steps=[('fill_empty_strings',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                   ('strip_spaces',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                   ('to_lower_case',
#                                    FunctionTransformer(feature_names...
#                                   ('normalize_unicode',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function normalize_unicode_fn at 0x7fa8842c9f80>))])),
#                  ('dietary_habits_mapping',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function map_dietary_habits_fn at 0x7fa8842ca200>)),
#                  ('dietary_habits_encoding',
#                   CustomEncoder(categories=[['unhealthy', 'moderate',
#                                              'healthy']]))]),
#  'degree_pipeline': Pipeline(steps=[('default_cat_pipeline',
#                   Pipeline(steps=[('fill_empty_strings',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                   ('strip_spaces',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                   ('to_lower_case',
#                                    FunctionTransformer(feature_names...
#                   FunctionTransformer(feature_names_out=<function map_degree_feature_names at 0x7fa8842ca340>,
#                                       func=<function map_degree_fn at 0x7fa8842ca520>)),
#                  ('degree_encoding',
#                   ColumnTransformer(transformers=[('degree_field_encoding',
#                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                  sparse_output=False),
#                                                    ['degree_field']),
#                                                   ('degree_level_encoding',
#                                                    CustomEncoder(categories=[['unknown',
#                                                                               'high_school',
#                                                                               'bachelor',
#                                                                               'master',
#                                                                               'doctorate']]),
#                                                    ['degree_level'])]))]),
#  'suicidal_thoughts_pipeline': Pipeline(steps=[('default_cat_pipeline',
#                   Pipeline(steps=[('fill_empty_strings',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                   ('strip_spaces',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                   ('to_lower_case',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#                                   ('normalize_unicode',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function normalize_unicode_fn at 0x7fa8842c9f80>))])),
#                  ('suididal_thoughts_encoding',
#                   OneHotEncoder(handle_unknown='ignore', sparse_output=False))]),
#  'family_history_pipeline': Pipeline(steps=[('default_cat_pipeline',
#                   Pipeline(steps=[('fill_empty_strings',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                   ('strip_spaces',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                   ('to_lower_case',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#                                   ('normalize_unicode',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function normalize_unicode_fn at 0x7fa8842c9f80>))])),
#                  ('family_history_encoding',
#                   OneHotEncoder(handle_unknown='ignore', sparse_output=False))]),
#  'city_pipeline': Pipeline(steps=[('default_cat_pipeline',
#                   Pipeline(steps=[('fill_empty_strings',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                   ('strip_spaces',
#                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                        func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                                   ('to_lower_case',
#                                    FunctionTransformer(feature_names...
#                                       func=<function map_city_fn at 0x7fa8842ca700>)),
#                  ('city_verification',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function verify_city_fn at 0x7fa8842caa20>)),
#                  ('city_depression_ratio', MapCityDepressionRatio()),
#                  ('city_cluster_similarity', ClusterSimilarityTransformer()),
#                  ('drop_lat_long',
#                   ConditionalDropper(columns_to_drop=['city', 'lat', 'long']))]),
#  'age_pipeline': Pipeline(steps=[('default_num_pipeline',
#                   Pipeline(steps=[('imputer',
#                                    SimpleImputer(strategy='median'))])),
#                  ('map_age_bins',
#                   FunctionTransformer(feature_names_out=<function map_age_bins_feature_names at 0x7fa8842cb560>,
#                                       func=<function map_age_bins_fn at 0x7fa8842cb600>)),
#                  ('age_encoding',
#                   ColumnTransformer(transformers=[('age_range_encoding',
#                                                    CustomEncoder(categories=[['18_to_23',
#                                                                               '23_to_28',
#                                                                               '28_to_33',
#                                                                               'gte_33']]),
#                                                    ['age_range'])]))]),
#  'cgpa_pipeline': Pipeline(steps=[('default_num_pipeline',
#                   Pipeline(steps=[('imputer',
#                                    SimpleImputer(strategy='median'))])),
#                  ('map_cgpa_bins',
#                   FunctionTransformer(feature_names_out=<function map_cgpa_bins_feature_names at 0x7fa8842cb6a0>,
#                                       func=<function map_cgpa_bins_fn at 0x7fa8842cb740>)),
#                  ('cgpa_encoding',
#                   ColumnTransformer(transformers=[('cgpa_range_encoding',
#                                                    CustomEncoder(categories=[['lt_4',
#                                                                               '4_to_7',
#                                                                               'gte_7']]),
#                                                    ['cgpa_range'])]))]),
#  'hours_pipeline': Pipeline(steps=[('default_num_pipeline',
#                   Pipeline(steps=[('imputer',
#                                    SimpleImputer(strategy='median'))])),
#                  ('map_hours_bins',
#                   FunctionTransformer(feature_names_out=<function map_hours_bins_feature_names at 0x7fa8842cb7e0>,
#                                       func=<function map_hours_bins_fn at 0x7fa8842cb880>)),
#                  ('hours_encoding',
#                   ColumnTransformer(transformers=[('hours_range_encoding',
#                                                    CustomEncoder(categories=[['lt_4',
#                                                                               '4_to_8',
#                                                                               'gte_8']]),
#                                                    ['hours_range'])]))]),
#  'ratings_column_pipeline': Pipeline(steps=[('default_num_pipeline',
#                   Pipeline(steps=[('imputer',
#                                    SimpleImputer(strategy='median'))]))]),
#  'preprocess_gender__memory': None,
#  'preprocess_gender__steps': [('default_cat_pipeline',
#    Pipeline(steps=[('fill_empty_strings',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                    ('strip_spaces',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                    ('to_lower_case',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#                    ('normalize_unicode',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function normalize_unicode_fn at 0x7fa8842c9f80>))])),
#   ('encode_gender',
#    OneHotEncoder(handle_unknown='ignore', sparse_output=False))],
#  'preprocess_gender__transform_input': None,
#  'preprocess_gender__verbose': False,
#  'preprocess_gender__default_cat_pipeline': Pipeline(steps=[('fill_empty_strings',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                  ('strip_spaces',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                  ('to_lower_case',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#                  ('normalize_unicode',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function normalize_unicode_fn at 0x7fa8842c9f80>))]),
#  'preprocess_gender__encode_gender': OneHotEncoder(handle_unknown='ignore', sparse_output=False),
#  'preprocess_gender__default_cat_pipeline__memory': None,
#  'preprocess_gender__default_cat_pipeline__steps': [('fill_empty_strings',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#   ('strip_spaces',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function strip_spaces_fn at 0x7fa884208f40>)),
#   ('to_lower_case',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#   ('normalize_unicode',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function normalize_unicode_fn at 0x7fa8842c9f80>))],
#  'preprocess_gender__default_cat_pipeline__transform_input': None,
#  'preprocess_gender__default_cat_pipeline__verbose': False,
#  'preprocess_gender__default_cat_pipeline__fill_empty_strings': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function fill_empty_strings_fn at 0x7fa884208c20>),
#  'preprocess_gender__default_cat_pipeline__strip_spaces': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function strip_spaces_fn at 0x7fa884208f40>),
#  'preprocess_gender__default_cat_pipeline__to_lower_case': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function to_lower_case_fn at 0x7fa8842a3240>),
#  'preprocess_gender__default_cat_pipeline__normalize_unicode': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function normalize_unicode_fn at 0x7fa8842c9f80>),
#  'preprocess_gender__default_cat_pipeline__fill_empty_strings__accept_sparse': False,
#  'preprocess_gender__default_cat_pipeline__fill_empty_strings__check_inverse': True,
#  'preprocess_gender__default_cat_pipeline__fill_empty_strings__feature_names_out': 'one-to-one',
#  'preprocess_gender__default_cat_pipeline__fill_empty_strings__func': <function src.utils.categorical_preprocessing.fill_empty_strings_fn(df, columns=None)>,
#  'preprocess_gender__default_cat_pipeline__fill_empty_strings__inv_kw_args': None,
#  'preprocess_gender__default_cat_pipeline__fill_empty_strings__inverse_func': None,
#  'preprocess_gender__default_cat_pipeline__fill_empty_strings__kw_args': None,
#  'preprocess_gender__default_cat_pipeline__fill_empty_strings__validate': False,
#  'preprocess_gender__default_cat_pipeline__strip_spaces__accept_sparse': False,
#  'preprocess_gender__default_cat_pipeline__strip_spaces__check_inverse': True,
#  'preprocess_gender__default_cat_pipeline__strip_spaces__feature_names_out': 'one-to-one',
#  'preprocess_gender__default_cat_pipeline__strip_spaces__func': <function src.utils.categorical_preprocessing.strip_spaces_fn(df, colmns=None)>,
#  'preprocess_gender__default_cat_pipeline__strip_spaces__inv_kw_args': None,
#  'preprocess_gender__default_cat_pipeline__strip_spaces__inverse_func': None,
#  'preprocess_gender__default_cat_pipeline__strip_spaces__kw_args': None,
#  'preprocess_gender__default_cat_pipeline__strip_spaces__validate': False,
#  'preprocess_gender__default_cat_pipeline__to_lower_case__accept_sparse': False,
#  'preprocess_gender__default_cat_pipeline__to_lower_case__check_inverse': True,
#  'preprocess_gender__default_cat_pipeline__to_lower_case__feature_names_out': 'one-to-one',
#  'preprocess_gender__default_cat_pipeline__to_lower_case__func': <function src.utils.categorical_preprocessing.to_lower_case_fn(df)>,
#  'preprocess_gender__default_cat_pipeline__to_lower_case__inv_kw_args': None,
#  'preprocess_gender__default_cat_pipeline__to_lower_case__inverse_func': None,
#  'preprocess_gender__default_cat_pipeline__to_lower_case__kw_args': None,
#  'preprocess_gender__default_cat_pipeline__to_lower_case__validate': False,
#  'preprocess_gender__default_cat_pipeline__normalize_unicode__accept_sparse': False,
#  'preprocess_gender__default_cat_pipeline__normalize_unicode__check_inverse': True,
#  'preprocess_gender__default_cat_pipeline__normalize_unicode__feature_names_out': 'one-to-one',
#  'preprocess_gender__default_cat_pipeline__normalize_unicode__func': <function src.utils.categorical_preprocessing.normalize_unicode_fn(df)>,
#  'preprocess_gender__default_cat_pipeline__normalize_unicode__inv_kw_args': None,
#  'preprocess_gender__default_cat_pipeline__normalize_unicode__inverse_func': None,
#  'preprocess_gender__default_cat_pipeline__normalize_unicode__kw_args': None,
#  'preprocess_gender__default_cat_pipeline__normalize_unicode__validate': False,
#  'preprocess_gender__encode_gender__categories': 'auto',
#  'preprocess_gender__encode_gender__drop': None,
#  'preprocess_gender__encode_gender__dtype': numpy.float64,
#  'preprocess_gender__encode_gender__feature_name_combiner': 'concat',
#  'preprocess_gender__encode_gender__handle_unknown': 'ignore',
#  'preprocess_gender__encode_gender__max_categories': None,
#  'preprocess_gender__encode_gender__min_frequency': None,
#  'preprocess_gender__encode_gender__sparse_output': False,
#  'preprocess_profession__memory': None,
#  'preprocess_profession__steps': [('default_cat_pipeline',
#    Pipeline(steps=[('fill_empty_strings',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                    ('strip_spaces',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                    ('to_lower_case',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#                    ('normalize_unicode',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function normalize_unicode_fn at 0x7fa8842c9f80>))])),
#   ('map_profession',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function map_working_profession_fn at 0x7fa8842ca020>)),
#   ('encode_profession',
#    OneHotEncoder(handle_unknown='ignore', sparse_output=False))],
#  'preprocess_profession__transform_input': None,
#  'preprocess_profession__verbose': False,
#  'preprocess_profession__default_cat_pipeline': Pipeline(steps=[('fill_empty_strings',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                  ('strip_spaces',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                  ('to_lower_case',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#                  ('normalize_unicode',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function normalize_unicode_fn at 0x7fa8842c9f80>))]),
#  'preprocess_profession__map_profession': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function map_working_profession_fn at 0x7fa8842ca020>),
#  'preprocess_profession__encode_profession': OneHotEncoder(handle_unknown='ignore', sparse_output=False),
#  'preprocess_profession__default_cat_pipeline__memory': None,
#  'preprocess_profession__default_cat_pipeline__steps': [('fill_empty_strings',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#   ('strip_spaces',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function strip_spaces_fn at 0x7fa884208f40>)),
#   ('to_lower_case',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#   ('normalize_unicode',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function normalize_unicode_fn at 0x7fa8842c9f80>))],
#  'preprocess_profession__default_cat_pipeline__transform_input': None,
#  'preprocess_profession__default_cat_pipeline__verbose': False,
#  'preprocess_profession__default_cat_pipeline__fill_empty_strings': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function fill_empty_strings_fn at 0x7fa884208c20>),
#  'preprocess_profession__default_cat_pipeline__strip_spaces': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function strip_spaces_fn at 0x7fa884208f40>),
#  'preprocess_profession__default_cat_pipeline__to_lower_case': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function to_lower_case_fn at 0x7fa8842a3240>),
#  'preprocess_profession__default_cat_pipeline__normalize_unicode': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function normalize_unicode_fn at 0x7fa8842c9f80>),
#  'preprocess_profession__default_cat_pipeline__fill_empty_strings__accept_sparse': False,
#  'preprocess_profession__default_cat_pipeline__fill_empty_strings__check_inverse': True,
#  'preprocess_profession__default_cat_pipeline__fill_empty_strings__feature_names_out': 'one-to-one',
#  'preprocess_profession__default_cat_pipeline__fill_empty_strings__func': <function src.utils.categorical_preprocessing.fill_empty_strings_fn(df, columns=None)>,
#  'preprocess_profession__default_cat_pipeline__fill_empty_strings__inv_kw_args': None,
#  'preprocess_profession__default_cat_pipeline__fill_empty_strings__inverse_func': None,
#  'preprocess_profession__default_cat_pipeline__fill_empty_strings__kw_args': None,
#  'preprocess_profession__default_cat_pipeline__fill_empty_strings__validate': False,
#  'preprocess_profession__default_cat_pipeline__strip_spaces__accept_sparse': False,
#  'preprocess_profession__default_cat_pipeline__strip_spaces__check_inverse': True,
#  'preprocess_profession__default_cat_pipeline__strip_spaces__feature_names_out': 'one-to-one',
#  'preprocess_profession__default_cat_pipeline__strip_spaces__func': <function src.utils.categorical_preprocessing.strip_spaces_fn(df, colmns=None)>,
#  'preprocess_profession__default_cat_pipeline__strip_spaces__inv_kw_args': None,
#  'preprocess_profession__default_cat_pipeline__strip_spaces__inverse_func': None,
#  'preprocess_profession__default_cat_pipeline__strip_spaces__kw_args': None,
#  'preprocess_profession__default_cat_pipeline__strip_spaces__validate': False,
#  'preprocess_profession__default_cat_pipeline__to_lower_case__accept_sparse': False,
#  'preprocess_profession__default_cat_pipeline__to_lower_case__check_inverse': True,
#  'preprocess_profession__default_cat_pipeline__to_lower_case__feature_names_out': 'one-to-one',
#  'preprocess_profession__default_cat_pipeline__to_lower_case__func': <function src.utils.categorical_preprocessing.to_lower_case_fn(df)>,
#  'preprocess_profession__default_cat_pipeline__to_lower_case__inv_kw_args': None,
#  'preprocess_profession__default_cat_pipeline__to_lower_case__inverse_func': None,
#  'preprocess_profession__default_cat_pipeline__to_lower_case__kw_args': None,
#  'preprocess_profession__default_cat_pipeline__to_lower_case__validate': False,
#  'preprocess_profession__default_cat_pipeline__normalize_unicode__accept_sparse': False,
#  'preprocess_profession__default_cat_pipeline__normalize_unicode__check_inverse': True,
#  'preprocess_profession__default_cat_pipeline__normalize_unicode__feature_names_out': 'one-to-one',
#  'preprocess_profession__default_cat_pipeline__normalize_unicode__func': <function src.utils.categorical_preprocessing.normalize_unicode_fn(df)>,
#  'preprocess_profession__default_cat_pipeline__normalize_unicode__inv_kw_args': None,
#  'preprocess_profession__default_cat_pipeline__normalize_unicode__inverse_func': None,
#  'preprocess_profession__default_cat_pipeline__normalize_unicode__kw_args': None,
#  'preprocess_profession__default_cat_pipeline__normalize_unicode__validate': False,
#  'preprocess_profession__map_profession__accept_sparse': False,
#  'preprocess_profession__map_profession__check_inverse': True,
#  'preprocess_profession__map_profession__feature_names_out': 'one-to-one',
#  'preprocess_profession__map_profession__func': <function src.utils.categorical_preprocessing.map_working_profession_fn(df)>,
#  'preprocess_profession__map_profession__inv_kw_args': None,
#  'preprocess_profession__map_profession__inverse_func': None,
#  'preprocess_profession__map_profession__kw_args': None,
#  'preprocess_profession__map_profession__validate': False,
#  'preprocess_profession__encode_profession__categories': 'auto',
#  'preprocess_profession__encode_profession__drop': None,
#  'preprocess_profession__encode_profession__dtype': numpy.float64,
#  'preprocess_profession__encode_profession__feature_name_combiner': 'concat',
#  'preprocess_profession__encode_profession__handle_unknown': 'ignore',
#  'preprocess_profession__encode_profession__max_categories': None,
#  'preprocess_profession__encode_profession__min_frequency': None,
#  'preprocess_profession__encode_profession__sparse_output': False,
#  'sleep_duration_pipeline__memory': None,
#  'sleep_duration_pipeline__steps': [('default_cat_pipeline',
#    Pipeline(steps=[('fill_empty_strings',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                    ('strip_spaces',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                    ('to_lower_case',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#                    ('normalize_unicode',
#                     FunctionTransformer(feature_names_out='one-to-one',
#                                         func=<function normalize_unicode_fn at 0x7fa8842c9f80>))])),
#   ('sleep_duration_clean',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function clean_sleep_duration_fn at 0x7fa8842ca0c0>)),
#   ('sleep_duration_mapping',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function map_sleep_duration_fn at 0x7fa8842ca160>)),
#   ('sleep_duration_encoding',
#    CustomEncoder(categories=[['lt_5', 'bt_5_6', 'bt_7_8', 'gt_8']]))],
#  'sleep_duration_pipeline__transform_input': None,
#  'sleep_duration_pipeline__verbose': False,
#  'sleep_duration_pipeline__default_cat_pipeline': Pipeline(steps=[('fill_empty_strings',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                  ('strip_spaces',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function strip_spaces_fn at 0x7fa884208f40>)),
#                  ('to_lower_case',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#                  ('normalize_unicode',
#                   FunctionTransformer(feature_names_out='one-to-one',
#                                       func=<function normalize_unicode_fn at 0x7fa8842c9f80>))]),
#  'sleep_duration_pipeline__sleep_duration_clean': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function clean_sleep_duration_fn at 0x7fa8842ca0c0>),
#  'sleep_duration_pipeline__sleep_duration_mapping': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function map_sleep_duration_fn at 0x7fa8842ca160>),
#  'sleep_duration_pipeline__sleep_duration_encoding': CustomEncoder(categories=[['lt_5', 'bt_5_6', 'bt_7_8', 'gt_8']]),
#  'sleep_duration_pipeline__default_cat_pipeline__memory': None,
#  'sleep_duration_pipeline__default_cat_pipeline__steps': [('fill_empty_strings',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#   ('strip_spaces',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function strip_spaces_fn at 0x7fa884208f40>)),
#   ('to_lower_case',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function to_lower_case_fn at 0x7fa8842a3240>)),
#   ('normalize_unicode',
#    FunctionTransformer(feature_names_out='one-to-one',
#                        func=<function normalize_unicode_fn at 0x7fa8842c9f80>))],
#  'sleep_duration_pipeline__default_cat_pipeline__transform_input': None,
#  'sleep_duration_pipeline__default_cat_pipeline__verbose': False,
#  'sleep_duration_pipeline__default_cat_pipeline__fill_empty_strings': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function fill_empty_strings_fn at 0x7fa884208c20>),
#  'sleep_duration_pipeline__default_cat_pipeline__strip_spaces': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function strip_spaces_fn at 0x7fa884208f40>),
#  'sleep_duration_pipeline__default_cat_pipeline__to_lower_case': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function to_lower_case_fn at 0x7fa8842a3240>),
#  'sleep_duration_pipeline__default_cat_pipeline__normalize_unicode': FunctionTransformer(feature_names_out='one-to-one',
#                      func=<function normalize_unicode_fn at 0x7fa8842c9f80>),
#  'sleep_duration_pipeline__default_cat_pipeline__fill_empty_strings__accept_sparse': False,
#  'sleep_duration_pipeline__default_cat_pipeline__fill_empty_strings__check_inverse': True,
# ...
#  'city_pipeline__default_cat_pipeline__strip_spaces__kw_args': None,
#  'city_pipeline__default_cat_pipeline__strip_spaces__validate': False,
#  'city_pipeline__default_cat_pipeline__to_lower_case__accept_sparse': False,
#  'city_pipeline__default_cat_pipeline__to_lower_case__check_inverse': True,
#  'city_pipeline__default_cat_pipeline__to_lower_case__feature_names_out': 'one-to-one',
#  'city_pipeline__default_cat_pipeline__to_lower_case__func': <function src.utils.categorical_preprocessing.to_lower_case_fn(df)>,
#  'city_pipeline__default_cat_pipeline__to_lower_case__inv_kw_args': None,
#  'city_pipeline__default_cat_pipeline__to_lower_case__inverse_func': None,
#  'city_pipeline__default_cat_pipeline__to_lower_case__kw_args': None,
#  'city_pipeline__default_cat_pipeline__to_lower_case__validate': False,
#  'city_pipeline__default_cat_pipeline__normalize_unicode__accept_sparse': False,
#  'city_pipeline__default_cat_pipeline__normalize_unicode__check_inverse': True,
#  'city_pipeline__default_cat_pipeline__normalize_unicode__feature_names_out': 'one-to-one',
#  'city_pipeline__default_cat_pipeline__normalize_unicode__func': <function src.utils.categorical_preprocessing.normalize_unicode_fn(df)>,
#  'city_pipeline__default_cat_pipeline__normalize_unicode__inv_kw_args': None,
#  'city_pipeline__default_cat_pipeline__normalize_unicode__inverse_func': None,
#  'city_pipeline__default_cat_pipeline__normalize_unicode__kw_args': None,
#  'city_pipeline__default_cat_pipeline__normalize_unicode__validate': False,
#  'city_pipeline__city_clean__accept_sparse': False,
#  'city_pipeline__city_clean__check_inverse': True,
#  'city_pipeline__city_clean__feature_names_out': 'one-to-one',
#  'city_pipeline__city_clean__func': <function src.utils.categorical_preprocessing.clean_city_fn(df)>,
#  'city_pipeline__city_clean__inv_kw_args': None,
#  'city_pipeline__city_clean__inverse_func': None,
#  'city_pipeline__city_clean__kw_args': None,
#  'city_pipeline__city_clean__validate': False,
#  'city_pipeline__rename_city__accept_sparse': False,
#  'city_pipeline__rename_city__check_inverse': True,
#  'city_pipeline__rename_city__feature_names_out': 'one-to-one',
#  'city_pipeline__rename_city__func': <function src.utils.categorical_preprocessing.rename_city_fn(df)>,
#  'city_pipeline__rename_city__inv_kw_args': None,
#  'city_pipeline__rename_city__inverse_func': None,
#  'city_pipeline__rename_city__kw_args': None,
#  'city_pipeline__rename_city__validate': False,
#  'city_pipeline__city_mapping__accept_sparse': False,
#  'city_pipeline__city_mapping__check_inverse': True,
#  'city_pipeline__city_mapping__feature_names_out': <function src.utils.categorical_preprocessing.map_city_feature_names(function_transformer, feature_names_in)>,
#  'city_pipeline__city_mapping__func': <function src.utils.categorical_preprocessing.map_city_fn(df)>,
#  'city_pipeline__city_mapping__inv_kw_args': None,
#  'city_pipeline__city_mapping__inverse_func': None,
#  'city_pipeline__city_mapping__kw_args': None,
#  'city_pipeline__city_mapping__validate': False,
#  'city_pipeline__city_verification__accept_sparse': False,
#  'city_pipeline__city_verification__check_inverse': True,
#  'city_pipeline__city_verification__feature_names_out': 'one-to-one',
#  'city_pipeline__city_verification__func': <function src.utils.categorical_preprocessing.verify_city_fn(df)>,
#  'city_pipeline__city_verification__inv_kw_args': None,
#  'city_pipeline__city_verification__inverse_func': None,
#  'city_pipeline__city_verification__kw_args': None,
#  'city_pipeline__city_verification__validate': False,
#  'city_pipeline__city_cluster_similarity__gamma': 1.0,
#  'city_pipeline__city_cluster_similarity__n_clusters': 5,
#  'city_pipeline__city_cluster_similarity__random_state': None,
#  'city_pipeline__drop_lat_long__active': True,
#  'city_pipeline__drop_lat_long__columns_to_drop': ['city', 'lat', 'long'],
#  'age_pipeline__memory': None,
#  'age_pipeline__steps': [('default_num_pipeline',
#    Pipeline(steps=[('imputer', SimpleImputer(strategy='median'))])),
#   ('map_age_bins',
#    FunctionTransformer(feature_names_out=<function map_age_bins_feature_names at 0x7fa8842cb560>,
#                        func=<function map_age_bins_fn at 0x7fa8842cb600>)),
#   ('age_encoding',
#    ColumnTransformer(transformers=[('age_range_encoding',
#                                     CustomEncoder(categories=[['18_to_23',
#                                                                '23_to_28',
#                                                                '28_to_33',
#                                                                'gte_33']]),
#                                     ['age_range'])]))],
#  'age_pipeline__transform_input': None,
#  'age_pipeline__verbose': False,
#  'age_pipeline__default_num_pipeline': Pipeline(steps=[('imputer', SimpleImputer(strategy='median'))]),
#  'age_pipeline__map_age_bins': FunctionTransformer(feature_names_out=<function map_age_bins_feature_names at 0x7fa8842cb560>,
#                      func=<function map_age_bins_fn at 0x7fa8842cb600>),
#  'age_pipeline__age_encoding': ColumnTransformer(transformers=[('age_range_encoding',
#                                   CustomEncoder(categories=[['18_to_23',
#                                                              '23_to_28',
#                                                              '28_to_33',
#                                                              'gte_33']]),
#                                   ['age_range'])]),
#  'age_pipeline__default_num_pipeline__memory': None,
#  'age_pipeline__default_num_pipeline__steps': [('imputer',
#    SimpleImputer(strategy='median'))],
#  'age_pipeline__default_num_pipeline__transform_input': None,
#  'age_pipeline__default_num_pipeline__verbose': False,
#  'age_pipeline__default_num_pipeline__imputer': SimpleImputer(strategy='median'),
#  'age_pipeline__default_num_pipeline__imputer__add_indicator': False,
#  'age_pipeline__default_num_pipeline__imputer__copy': True,
#  'age_pipeline__default_num_pipeline__imputer__fill_value': None,
#  'age_pipeline__default_num_pipeline__imputer__keep_empty_features': False,
#  'age_pipeline__default_num_pipeline__imputer__missing_values': nan,
#  'age_pipeline__default_num_pipeline__imputer__strategy': 'median',
#  'age_pipeline__map_age_bins__accept_sparse': False,
#  'age_pipeline__map_age_bins__check_inverse': True,
#  'age_pipeline__map_age_bins__feature_names_out': <function src.utils.numerical_preprocessing.map_age_bins_feature_names(function_transformer, feature_names_in)>,
#  'age_pipeline__map_age_bins__func': <function src.utils.numerical_preprocessing.map_age_bins_fn(df)>,
#  'age_pipeline__map_age_bins__inv_kw_args': None,
#  'age_pipeline__map_age_bins__inverse_func': None,
#  'age_pipeline__map_age_bins__kw_args': None,
#  'age_pipeline__map_age_bins__validate': False,
#  'age_pipeline__age_encoding__force_int_remainder_cols': True,
#  'age_pipeline__age_encoding__n_jobs': None,
#  'age_pipeline__age_encoding__remainder': 'drop',
#  'age_pipeline__age_encoding__sparse_threshold': 0.3,
#  'age_pipeline__age_encoding__transformer_weights': None,
#  'age_pipeline__age_encoding__transformers': [('age_range_encoding',
#    CustomEncoder(categories=[['18_to_23', '23_to_28', '28_to_33', 'gte_33']]),
#    ['age_range'])],
#  'age_pipeline__age_encoding__verbose': False,
#  'age_pipeline__age_encoding__verbose_feature_names_out': True,
#  'age_pipeline__age_encoding__age_range_encoding': CustomEncoder(categories=[['18_to_23', '23_to_28', '28_to_33', 'gte_33']]),
#  'age_pipeline__age_encoding__age_range_encoding__categories': [['18_to_23',
#    '23_to_28',
#    '28_to_33',
#    'gte_33']],
#  'age_pipeline__age_encoding__age_range_encoding__encoding': 'onehot',
#  'cgpa_pipeline__memory': None,
#  'cgpa_pipeline__steps': [('default_num_pipeline',
#    Pipeline(steps=[('imputer', SimpleImputer(strategy='median'))])),
#   ('map_cgpa_bins',
#    FunctionTransformer(feature_names_out=<function map_cgpa_bins_feature_names at 0x7fa8842cb6a0>,
#                        func=<function map_cgpa_bins_fn at 0x7fa8842cb740>)),
#   ('cgpa_encoding',
#    ColumnTransformer(transformers=[('cgpa_range_encoding',
#                                     CustomEncoder(categories=[['lt_4', '4_to_7',
#                                                                'gte_7']]),
#                                     ['cgpa_range'])]))],
#  'cgpa_pipeline__transform_input': None,
#  'cgpa_pipeline__verbose': False,
#  'cgpa_pipeline__default_num_pipeline': Pipeline(steps=[('imputer', SimpleImputer(strategy='median'))]),
#  'cgpa_pipeline__map_cgpa_bins': FunctionTransformer(feature_names_out=<function map_cgpa_bins_feature_names at 0x7fa8842cb6a0>,
#                      func=<function map_cgpa_bins_fn at 0x7fa8842cb740>),
#  'cgpa_pipeline__cgpa_encoding': ColumnTransformer(transformers=[('cgpa_range_encoding',
#                                   CustomEncoder(categories=[['lt_4', '4_to_7',
#                                                              'gte_7']]),
#                                   ['cgpa_range'])]),
#  'cgpa_pipeline__default_num_pipeline__memory': None,
#  'cgpa_pipeline__default_num_pipeline__steps': [('imputer',
#    SimpleImputer(strategy='median'))],
#  'cgpa_pipeline__default_num_pipeline__transform_input': None,
#  'cgpa_pipeline__default_num_pipeline__verbose': False,
#  'cgpa_pipeline__default_num_pipeline__imputer': SimpleImputer(strategy='median'),
#  'cgpa_pipeline__default_num_pipeline__imputer__add_indicator': False,
#  'cgpa_pipeline__default_num_pipeline__imputer__copy': True,
#  'cgpa_pipeline__default_num_pipeline__imputer__fill_value': None,
#  'cgpa_pipeline__default_num_pipeline__imputer__keep_empty_features': False,
#  'cgpa_pipeline__default_num_pipeline__imputer__missing_values': nan,
#  'cgpa_pipeline__default_num_pipeline__imputer__strategy': 'median',
#  'cgpa_pipeline__map_cgpa_bins__accept_sparse': False,
#  'cgpa_pipeline__map_cgpa_bins__check_inverse': True,
#  'cgpa_pipeline__map_cgpa_bins__feature_names_out': <function src.utils.numerical_preprocessing.map_cgpa_bins_feature_names(function_transformer, feature_names_in)>,
#  'cgpa_pipeline__map_cgpa_bins__func': <function src.utils.numerical_preprocessing.map_cgpa_bins_fn(df)>,
#  'cgpa_pipeline__map_cgpa_bins__inv_kw_args': None,
#  'cgpa_pipeline__map_cgpa_bins__inverse_func': None,
#  'cgpa_pipeline__map_cgpa_bins__kw_args': None,
#  'cgpa_pipeline__map_cgpa_bins__validate': False,
#  'cgpa_pipeline__cgpa_encoding__force_int_remainder_cols': True,
#  'cgpa_pipeline__cgpa_encoding__n_jobs': None,
#  'cgpa_pipeline__cgpa_encoding__remainder': 'drop',
#  'cgpa_pipeline__cgpa_encoding__sparse_threshold': 0.3,
#  'cgpa_pipeline__cgpa_encoding__transformer_weights': None,
#  'cgpa_pipeline__cgpa_encoding__transformers': [('cgpa_range_encoding',
#    CustomEncoder(categories=[['lt_4', '4_to_7', 'gte_7']]),
#    ['cgpa_range'])],
#  'cgpa_pipeline__cgpa_encoding__verbose': False,
#  'cgpa_pipeline__cgpa_encoding__verbose_feature_names_out': True,
#  'cgpa_pipeline__cgpa_encoding__cgpa_range_encoding': CustomEncoder(categories=[['lt_4', '4_to_7', 'gte_7']]),
#  'cgpa_pipeline__cgpa_encoding__cgpa_range_encoding__categories': [['lt_4',
#    '4_to_7',
#    'gte_7']],
#  'cgpa_pipeline__cgpa_encoding__cgpa_range_encoding__encoding': 'onehot',
#  'hours_pipeline__memory': None,
#  'hours_pipeline__steps': [('default_num_pipeline',
#    Pipeline(steps=[('imputer', SimpleImputer(strategy='median'))])),
#   ('map_hours_bins',
#    FunctionTransformer(feature_names_out=<function map_hours_bins_feature_names at 0x7fa8842cb7e0>,
#                        func=<function map_hours_bins_fn at 0x7fa8842cb880>)),
#   ('hours_encoding',
#    ColumnTransformer(transformers=[('hours_range_encoding',
#                                     CustomEncoder(categories=[['lt_4', '4_to_8',
#                                                                'gte_8']]),
#                                     ['hours_range'])]))],
#  'hours_pipeline__transform_input': None,
#  'hours_pipeline__verbose': False,
#  'hours_pipeline__default_num_pipeline': Pipeline(steps=[('imputer', SimpleImputer(strategy='median'))]),
#  'hours_pipeline__map_hours_bins': FunctionTransformer(feature_names_out=<function map_hours_bins_feature_names at 0x7fa8842cb7e0>,
#                      func=<function map_hours_bins_fn at 0x7fa8842cb880>),
#  'hours_pipeline__hours_encoding': ColumnTransformer(transformers=[('hours_range_encoding',
#                                   CustomEncoder(categories=[['lt_4', '4_to_8',
#                                                              'gte_8']]),
#                                   ['hours_range'])]),
#  'hours_pipeline__default_num_pipeline__memory': None,
#  'hours_pipeline__default_num_pipeline__steps': [('imputer',
#    SimpleImputer(strategy='median'))],
#  'hours_pipeline__default_num_pipeline__transform_input': None,
#  'hours_pipeline__default_num_pipeline__verbose': False,
#  'hours_pipeline__default_num_pipeline__imputer': SimpleImputer(strategy='median'),
#  'hours_pipeline__default_num_pipeline__imputer__add_indicator': False,
#  'hours_pipeline__default_num_pipeline__imputer__copy': True,
#  'hours_pipeline__default_num_pipeline__imputer__fill_value': None,
#  'hours_pipeline__default_num_pipeline__imputer__keep_empty_features': False,
#  'hours_pipeline__default_num_pipeline__imputer__missing_values': nan,
#  'hours_pipeline__default_num_pipeline__imputer__strategy': 'median',
#  'hours_pipeline__map_hours_bins__accept_sparse': False,
#  'hours_pipeline__map_hours_bins__check_inverse': True,
#  'hours_pipeline__map_hours_bins__feature_names_out': <function src.utils.numerical_preprocessing.map_hours_bins_feature_names(function_transformer, feature_names_in)>,
#  'hours_pipeline__map_hours_bins__func': <function src.utils.numerical_preprocessing.map_hours_bins_fn(df)>,
#  'hours_pipeline__map_hours_bins__inv_kw_args': None,
#  'hours_pipeline__map_hours_bins__inverse_func': None,
#  'hours_pipeline__map_hours_bins__kw_args': None,
#  'hours_pipeline__map_hours_bins__validate': False,
#  'hours_pipeline__hours_encoding__force_int_remainder_cols': True,
#  'hours_pipeline__hours_encoding__n_jobs': None,
#  'hours_pipeline__hours_encoding__remainder': 'drop',
#  'hours_pipeline__hours_encoding__sparse_threshold': 0.3,
#  'hours_pipeline__hours_encoding__transformer_weights': None,
#  'hours_pipeline__hours_encoding__transformers': [('hours_range_encoding',
#    CustomEncoder(categories=[['lt_4', '4_to_8', 'gte_8']]),
#    ['hours_range'])],
#  'hours_pipeline__hours_encoding__verbose': False,
#  'hours_pipeline__hours_encoding__verbose_feature_names_out': True,
#  'hours_pipeline__hours_encoding__hours_range_encoding': CustomEncoder(categories=[['lt_4', '4_to_8', 'gte_8']]),
#  'hours_pipeline__hours_encoding__hours_range_encoding__categories': [['lt_4',
#    '4_to_8',
#    'gte_8']],
#  'hours_pipeline__hours_encoding__hours_range_encoding__encoding': 'onehot',
#  'ratings_column_pipeline__memory': None,
#  'ratings_column_pipeline__steps': [('default_num_pipeline',
#    Pipeline(steps=[('imputer', SimpleImputer(strategy='median'))]))],
#  'ratings_column_pipeline__transform_input': None,
#  'ratings_column_pipeline__verbose': False,
#  'ratings_column_pipeline__default_num_pipeline': Pipeline(steps=[('imputer', SimpleImputer(strategy='median'))]),
#  'ratings_column_pipeline__default_num_pipeline__memory': None,
#  'ratings_column_pipeline__default_num_pipeline__steps': [('imputer',
#    SimpleImputer(strategy='median'))],
#  'ratings_column_pipeline__default_num_pipeline__transform_input': None,
#  'ratings_column_pipeline__default_num_pipeline__verbose': False,
#  'ratings_column_pipeline__default_num_pipeline__imputer': SimpleImputer(strategy='median'),
#  'ratings_column_pipeline__default_num_pipeline__imputer__add_indicator': False,
#  'ratings_column_pipeline__default_num_pipeline__imputer__copy': True,
#  'ratings_column_pipeline__default_num_pipeline__imputer__fill_value': None,
#  'ratings_column_pipeline__default_num_pipeline__imputer__keep_empty_features': False,
#  'ratings_column_pipeline__default_num_pipeline__imputer__missing_values': nan,
#  'ratings_column_pipeline__default_num_pipeline__imputer__strategy': 'median'}

# %%
model_pipeline = Pipeline([
    ("preprocessing", preprocessing.pipeline),
    ("normalizing", StandardScaler()),
    ("prediction", RandomForestClassifier(random_state=42))
])

scoring = ["recall", "precision", "f1"]

## experiment between onehot and ordinal encoding of various features.

param_grid = {
    "preprocessing__sleep_duration_pipeline__sleep_duration_encoding__encoding":["onehot", "ordinal"],
    "preprocessing__dietary_habits_pipeline__dietary_habits_encoding__encoding":["onehot", "ordinal"],
    "preprocessing__degree_pipeline__degree_encoding__degree_level_encoding__encoding":["onehot", "ordinal"],
    "preprocessing__age_pipeline__age_encoding__age_range_encoding__encoding":["onehot", "ordinal"],
    "preprocessing__cgpa_pipeline__cgpa_encoding__cgpa_range_encoding__encoding":["onehot", "ordinal"],
    "preprocessing__hours_pipeline__hours_encoding__hours_range_encoding__encoding":["onehot", "ordinal"],
    "prediction__n_estimators": [100,150,200,250,300,350,400,500],
    "prediction__criterion": ["gini", "entropy", "log_loss"],
    "prediction__max_features": ["sqrt", "log2", None]
}

grid_search = GridSearchCV(model_pipeline, param_grid, scoring=scoring, cv=3,n_jobs=-1,refit=refit_strategy)
grid_search.fit(X_train, y_train.values.ravel())
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocessing',
#                                         ColumnTransformer(transformers=[('preprocess_gender',
#                                                                          Pipeline(steps=[('default_cat_pipeline',
#                                                                                           Pipeline(steps=[('fill_empty_strings',
#                                                                                                            FunctionTransformer(feature_names_out='one-to-one',
#                                                                                                                                func=<function fill_empty_strings_fn at 0x7fa884208c20>)),
#                                                                                                           ('strip_spaces',
#                                                                                                            FunctionTransformer(feature_names_ou...
#                          'preprocessing__dietary_habits_pipeline__dietary_habits_encoding__encoding': ['onehot',
#                                                                                                        'ordinal'],
#                          'preprocessing__hours_pipeline__hours_encoding__hours_range_encoding__encoding': ['onehot',
#                                                                                                            'ordinal'],
#                          'preprocessing__sleep_duration_pipeline__sleep_duration_encoding__encoding': ['onehot',
#                                                                                                        'ordinal']},
#              refit=<function refit_strategy at 0x7fa884422980>,
#              scoring=['recall', 'precision', 'f1'])

# %%
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best Scores : {grid_search.best_index_}")
average_recall,average_precision,average_f1 = common.read_best_mean_grid_search_metrics(grid_search.cv_results_,grid_search.best_index_)
# Out:
# Best Parameters: {'prediction__criterion': 'gini', 'prediction__max_features': 'sqrt', 'prediction__n_estimators': 400, 'preprocessing__age_pipeline__age_encoding__age_range_encoding__encoding': 'onehot', 'preprocessing__cgpa_pipeline__cgpa_encoding__cgpa_range_encoding__encoding': 'ordinal', 'preprocessing__degree_pipeline__degree_encoding__degree_level_encoding__encoding': 'ordinal', 'preprocessing__dietary_habits_pipeline__dietary_habits_encoding__encoding': 'ordinal', 'preprocessing__hours_pipeline__hours_encoding__hours_range_encoding__encoding': 'ordinal', 'preprocessing__sleep_duration_pipeline__sleep_duration_encoding__encoding': 'onehot'}
# Best Scores : 414
# Mean Recall: 0.8835322926232018, Mean Precision: 0.8503987121482556,Mean F1: 0.8666254719048757

# %%
# commenting this code out to avoid overwriting the metrics file.
_, file_name = common.save_model(
    "Random Forest", "v2", grid_search.best_estimator_)
common.update_models_metrics("Random Forest", "v2", average_recall,
                             average_precision, average_f1, file_name=file_name)
common.update_model_params(
    "RandomForest", "v2", grid_search.best_params_)
# Out:
# [{'name': 'LogisticRegression',
#   'version': 'v1',
#   'params': {'prediction__C': 1,
#    'prediction__penalty': 'l1',
#    'prediction__solver': 'liblinear'}},
#  {'name': 'LogisticRegression',
#   'version': 'v2',
#   'params': {'prediction__C': 1,
#    'prediction__penalty': 'l2',
#    'prediction__solver': 'saga',
#    'preprocessing__age_pipeline__age_encoding__age_range_encoding__encoding': 'ordinal',
#    'preprocessing__cgpa_pipeline__cgpa_encoding__cgpa_range_encoding__encoding': 'ordinal',
#    'preprocessing__degree_pipeline__degree_encoding__degree_level_encoding__encoding': 'ordinal',
#    'preprocessing__dietary_habits_pipeline__dietary_habits_encoding__encoding': 'ordinal',
#    'preprocessing__hours_pipeline__hours_encoding__hours_range_encoding__encoding': 'onehot',
#    'preprocessing__sleep_duration_pipeline__sleep_duration_encoding__encoding': 'ordinal'}},
#  {'name': 'LinearSVC',
#   'version': 'v1',
#   'params': {'prediction__C': 10, 'prediction__penalty': 'l1'}},
#  {'name': 'LinearSVC',
#   'version': 'v2',
#   'params': {'prediction__C': 0.1,
#    'prediction__penalty': 'l1',
#    'preprocessing__age_pipeline__age_encoding__age_range_encoding__encoding': 'ordinal',
#    'preprocessing__cgpa_pipeline__cgpa_encoding__cgpa_range_encoding__encoding': 'ordinal',
#    'preprocessing__degree_pipeline__degree_encoding__degree_level_encoding__encoding': 'ordinal',
#    'preprocessing__dietary_habits_pipeline__dietary_habits_encoding__encoding': 'ordinal',
#    'preprocessing__hours_pipeline__hours_encoding__hours_range_encoding__encoding': 'onehot',
#    'preprocessing__sleep_duration_pipeline__sleep_duration_encoding__encoding': 'onehot'}},
#  {'name': 'RandomForest',
#   'version': 'v1',
#   'params': {'prediction__criterion': 'entropy',
#    'prediction__max_features': 'sqrt',
#    'prediction__n_estimators': 250}},
#  {'name': 'RandomForest',
#   'version': 'v1',
#   'params': {'prediction__criterion': 'log_loss',
#    'prediction__max_features': 'sqrt',
#    'prediction__n_estimators': 400}},
#  {'name': 'RandomForest',
#   'version': 'v2',
#   'params': {'prediction__criterion': 'gini',
#    'prediction__max_features': 'sqrt',
#    'prediction__n_estimators': 400,
#    'preprocessing__age_pipeline__age_encoding__age_range_encoding__encoding': 'onehot',
#    'preprocessing__cgpa_pipeline__cgpa_encoding__cgpa_range_encoding__encoding': 'ordinal',
#    'preprocessing__degree_pipeline__degree_encoding__degree_level_encoding__encoding': 'ordinal',
#    'preprocessing__dietary_habits_pipeline__dietary_habits_encoding__encoding': 'ordinal',
#    'preprocessing__hours_pipeline__hours_encoding__hours_range_encoding__encoding': 'ordinal',
#    'preprocessing__sleep_duration_pipeline__sleep_duration_encoding__encoding': 'onehot'}},
#  {'name': 'RandomForest',
#   'version': 'v2',
#   'params': {'prediction__criterion': 'gini',
#    'prediction__max_features': 'sqrt',
#    'prediction__n_estimators': 400,
#    'preprocessing__age_pipeline__age_encoding__age_range_encoding__encoding': 'onehot',
#    'preprocessing__cgpa_pipeline__cgpa_encoding__cgpa_range_encoding__encoding': 'ordinal',
#    'preprocessing__degree_pipeline__degree_encoding__degree_level_encoding__encoding': 'ordinal',
#    'preprocessing__dietary_habits_pipeline__dietary_habits_encoding__encoding': 'ordinal',
#    'preprocessing__hours_pipeline__hours_encoding__hours_range_encoding__encoding': 'ordinal',
#    'preprocessing__sleep_duration_pipeline__sleep_duration_encoding__encoding': 'onehot'}}]

# %% [markdown]
# Observations:
# * In general there is not significan't improvement between 2 versions of Random Forest and also between Random Forest and previous Linear Models.
